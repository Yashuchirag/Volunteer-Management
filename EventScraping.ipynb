# %%
import requests
from bs4 import BeautifulSoup

import re

import pandas as pd

# %%
def get_html_content(url):
    url_website = requests.get(url)
    return BeautifulSoup(url_website.text, "html.parser")

# %%
eventDeptDict = {'Communications and Engagement':'D/Coms', 'Climate Initiatives':'D/CI', 'Housing and Human Services':'d/hhs', 'Open Space and Mountain Parks':'d/osmp', 'Parks and Recreation':'d/parksrec', 'Public Works':'d/pw',}

# %%
#df_deptEventHtml = pd.DataFrame(index=eventDeptDict.keys(),columns=["HTML code for the department"])
dict_deptEventHtml = {}

for dept in eventDeptDict.keys():
    dict_deptEventHtml[dept] = get_html_content("https://countmein.bouldercolorado.gov/"+eventDeptDict[dept])

# %%
dict_deptEventHtml.keys()
# Out:
# dict_keys(['Communications and Engagement', 'Climate Initiatives', 'Housing and Human Services', 'Open Space and Mountain Parks', 'Parks and Recreation', 'Public Works'])

# %%
event_html={}

for dept in dict_deptEventHtml.keys():
    event_html[dept] = [html for html in dict_deptEventHtml[dept].find_all('tr')]

# %%
eventDetails = pd.DataFrame(columns=["Event Name", "Date and Time", "Event Description"])

for event_html_iter in event_html.values():
    for eventList in event_html_iter:
        event_name_element = eventList.find('a', attrs={"title": "Activity Details"})
        date_time_element = eventList.find('h5', attrs={"class": "margin-top-5"})
        description_element = eventList.find('p')
        
        # Check if elements are found before calling get_text()
        event_name = event_name_element.get_text() if event_name_element else None
        date_time = date_time_element.get_text() if date_time_element else None
        date_time_regex = r"(\d{1,2}\s[A-Za-z]+\s\d{4})\s+\|\s+(\d{2}:\d{2}\s[AP]M)"
        date, time = re.findall(date_time_regex, date_time)[0]
        description = description_element.get_text() if description_element else None
        
        # Append data to DataFrame only if all elements are found
        if all((event_name, date_time, description)):
            eventRow = pd.DataFrame({"Event Name": [event_name], "Date": [date], "Time": [time], "Event Description": [description]})
            eventDetails = pd.concat([eventDetails, eventRow], ignore_index=True)

eventDetails
# Out:
#   Tuesday, 30 April 2024 |   10:00 AM
#                      |   Shanahan Ridge / Lehigh
#  ('30 April 2024', '10:00 AM')
#
#   Sunday, 05 May 2024 |   09:00 AM
#                      |   Dry Creek
#  ('05 May 2024', '09:00 AM')
#
#   Sunday, 05 May 2024 |   02:00 PM
#                      |   Flagstaff Summit
#  |  Registration Required
#  ('05 May 2024', '02:00 PM')
#
#   Sunday, 05 May 2024 |   09:00 AM
#                      |   Dry Creek
#  ('05 May 2024', '09:00 AM')
#
#   Thursday, 09 May 2024 |   09:00 AM
#                      |   Flagstaff Summit
#  ('09 May 2024', '09:00 AM')
#
#   Saturday, 11 May 2024 |   09:00 AM
#                     |  Other OSMP Location
#  ('11 May 2024', '09:00 AM')
#
#   Sunday, 12 May 2024 |   10:00 AM
#                      |   Enchanted Mesa
#  |  Registration Required
#  ('12 May 2024', '10:00 AM')
#
#   Sunday, 12 May 2024 |   09:00 AM
#                      |   Chautauqua Ranger Cottage
#  ('12 May 2024', '09:00 AM')
#
#   Tuesday, 14 May 2024 |   09:30 AM
#                      |   Enchanted Mesa
#  ('14 May 2024', '09:30 AM')
#
#   Wednesday, 15 May 2024 |   09:00 AM
#                     |   Coal Creek
#  ('15 May 2024', '09:00 AM')
#
#   Wednesday, 08 May 2024 |   02:00 PM
#                      |   Violet Park
#  ('08 May 2024', '02:00 PM')
#
#   Wednesday, 08 May 2024 |   09:00 AM
#                      |   Wonderland Lake Park
#  ('08 May 2024', '09:00 AM')
#
#   Saturday, 11 May 2024 |   09:00 AM
#                      |   Valmont City Park North
#  ('11 May 2024', '09:00 AM')
#
#   Wednesday, 15 May 2024 |   09:00 AM
#                      |   Pearl Street Mall
#  ('15 May 2024', '09:00 AM')
#
#   Friday, 17 May 2024 |   09:00 AM
#                      |   Pearl Street Mall
#  ('17 May 2024', '09:00 AM')
#
#   Monday, 20 May 2024 |   09:00 AM
#                      |   Pearl Street Mall
#  ('20 May 2024', '09:00 AM')
#
#   Tuesday, 21 May 2024 |   09:00 AM
#                      |   Pearl Street Mall
#  ('21 May 2024', '09:00 AM')
#
#   Thursday, 23 May 2024 |   09:00 AM
#          ('23 May 2024', '09:00 AM')
#                                           Event Name Date and Time
# 0                           \nConnection in Nature\n           NaN  \
# 1              \nLet's Doo It!: Dog Waste Clean Up\n           NaN
# 2                                      \nWild Moms\n           NaN
# 3  \nConnecting with Nature Through Art (Older Ad...           NaN
# 4  \nRecovery and Wellness Series: Conscious Reco...           NaN
# 5  \nCANCELED: StoryTime: Hello Bees! (KIDS Ages ...           NaN
# 6  \nTrail Challenge Series: Flatirons Loop to En...           NaN
# 7  \nFind Your Village: An Event with Hiking Baby...           NaN
# 8    \nOlder Adults West Boulder Neighborhood Walk\n           NaN
#
#                                    Event Description           Date      Time
# 0  \n                Join OSMP Volunteer Naturali...  30 April 2024  10:00 AM
# 1  \n                Make your pup proud, and Let...    05 May 2024  09:00 AM
# 2  \n                While every mom is one-of-a-...    05 May 2024  02:00 PM
# 3  \n                Join volunteer naturalists B...    09 May 2024  09:00 AM
# 4  \n                A program geared towards tho...    11 May 2024  09:00 AM
# 5  \n                Let’s say hello to the bees ...    12 May 2024  10:00 AM
# 6  \n                The City of Boulder has over...    12 May 2024  09:00 AM
# 7  \n                Hitting the trails with litt...    14 May 2024  09:30 AM
# 8  \n                Come join Jane in an excitin...    23 May 2024  09:00 AM

# %%
eventDetails.replace('\n', '', regex=True, inplace=True)

# %%
eventDetails
# Out:
#                                           Event Name
# 0                               Connection in Nature  \
# 1                  Let's Doo It!: Dog Waste Clean Up
# 2                                          Wild Moms
# 3  Connecting with Nature Through Art (Older Adul...
# 4  Recovery and Wellness Series: Conscious Reconn...
# 5   CANCELED: StoryTime: Hello Bees! (KIDS Ages 3-6)
# 6  Trail Challenge Series: Flatirons Loop to Ench...
# 7  Find Your Village: An Event with Hiking Baby B...
# 8        Older Adults West Boulder Neighborhood Walk
#
#                                        Date and Time
# 0    Tuesday, 30 April 2024 |   10:00 AM         ...  \
# 1    Sunday, 05 May 2024 |   09:00 AM            ...
# 2    Sunday, 05 May 2024 |   02:00 PM            ...
# 3    Thursday, 09 May 2024 |   09:00 AM          ...
# 4    Saturday, 11 May 2024 |   09:00 AM          ...
# 5    Sunday, 12 May 2024 |   10:00 AM            ...
# 6    Sunday, 12 May 2024 |   09:00 AM            ...
# 7    Tuesday, 14 May 2024 |   09:30 AM           ...
# 8         Thursday, 23 May 2024 |   09:00 AM
#
#                                    Event Description
# 0                  Join OSMP Volunteer Naturalist...
# 1                  Make your pup proud, and Let’s...
# 2                  While every mom is one-of-a-ki...
# 3                  Join volunteer naturalists Bev...
# 4                  A program geared towards those...
# 5                  Let’s say hello to the bees to...
# 6                  The City of Boulder has over 4...
# 7                  Hitting the trails with little...
# 8                  Come join Jane in an exciting,...

# %%
import datetime
 
# using now() to get current time
current_time = datetime.datetime.now()

# %%
print(current_time)
# Out:
# 2024-04-30 23:04:21.659430
