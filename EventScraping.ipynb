# %%
import requests
from bs4 import BeautifulSoup

import re

import pandas as pd
# Out:
# C:\Users\vivek\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\vivek\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\vivek\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
def get_html_content(url):
    url_website = requests.get(url)
    return BeautifulSoup(url_website.text, "html.parser")

# %%
eventDeptDict = {'Communications and Engagement':'D/Coms', 'Climate Initiatives':'D/CI', 'Housing and Human Services':'d/hhs', 'Open Space and Mountain Parks':'d/osmp', 'Parks and Recreation':'d/parksrec', 'Public Works':'d/pw',}

# %%
#df_deptEventHtml = pd.DataFrame(index=eventDeptDict.keys(),columns=["HTML code for the department"])
dict_deptEventHtml = {}

for dept in eventDeptDict.keys():
    dict_deptEventHtml[dept] = get_html_content("https://countmein.bouldercolorado.gov/"+eventDeptDict[dept])

# %%
dict_deptEventHtml.keys()
# Out:
# dict_keys(['Communications and Engagement', 'Climate Initiatives', 'Housing and Human Services', 'Open Space and Mountain Parks', 'Parks and Recreation', 'Public Works'])

# %%
event_html={}

for dept in dict_deptEventHtml.keys():
    event_html[dept] = [html for html in dict_deptEventHtml[dept].find_all('tr')]

# %%
eventDetails = pd.DataFrame(columns=["Event Name", "Date and Time", "Event Description"])

for event_html_iter in event_html.values():
    for eventList in event_html_iter:
        event_name_element = eventList.find('a', attrs={"title": "Activity Details"})
        date_time_element = eventList.find('h5', attrs={"class": "margin-top-5"})
        description_element = eventList.find('p')
        
        # Check if elements are found before calling get_text()
        event_name = event_name_element.get_text() if event_name_element else None
        date_time = date_time_element.get_text() if date_time_element else None
        description = description_element.get_text() if description_element else None
        
        # Append data to DataFrame only if all elements are found
        if all((event_name, date_time, description)):
            eventRow = pd.DataFrame({"Event Name": [event_name], "Date and Time": [date_time], "Event Description": [description]})
            eventDetails = pd.concat([eventDetails, eventRow], ignore_index=True)

eventDetails
# Out:
#                                            Event Name  \
# 0            \nOSMP and the Arts: Flores de Migajon\n
# 1   \nFun for the Whole Flock: A Playful Birding P...
# 2   \nRecovery and Wellness Series: A Wellness Walk\n
# 3     \nEvery Day is Earth Day: A Biodiversity Hike\n
# 4    \nAdventure with a Ranger: Foundations of OSMP\n
# 5   \nConnection in Nature (for Older Adults age 6...
# 6   \nRecovery and Wellness Series: Conscious Reco...
# 7                \nSpring Beauty: A Wildflower Hike\n
# 8                            \nConnection in Nature\n
# 9     \nOlder Adults West Boulder Neighborhood Walk\n
# 10    \nOlder Adults West Boulder Neighborhood Walk\n
#
#                                         Date and Time  \
# 0   \n  Saturday, 13 April 2024 |   01:00 PM\n    ...
# 1   \n  Sunday, 14 April 2024 |   12:30 PM\n      ...
# 2   \n  Saturday, 20 April 2024 |   09:00 AM\n    ...
# 3   \n  Sunday, 21 April 2024 |   03:00 PM\n      ...
# 4   \n  Sunday, 21 April 2024 |   10:00 AM\n      ...
# 5   \n  Wednesday, 24 April 2024 |   10:00 AM\n   ...
# 6   \n  Saturday, 27 April 2024 |   09:00 AM\n    ...
# 7   \n  Sunday, 28 April 2024 |   01:00 PM\n      ...
# 8   \n  Tuesday, 30 April 2024 |   10:00 AM\n     ...
# 9   \n  Thursday, 25 April 2024 |   09:00 AM\n    ...
# 10   \n  Thursday, 23 May 2024 |   09:00 AM\n
#
#                                     Event Description
# 0   \n                Acompaña a Luna Cultura y Es...
# 1   \n                Let your playful self-fly an...
# 2   \n                Geared towards those in reco...
# 3   \n                From vast prairies to rugged...
# 4   \n                New to OSMP or looking to be...
# 5   \n                Join OSMP Volunteer Naturali...
# 6   \n                A program geared towards tho...
# 7   \n                Springtime in Boulder brings...
# 8   \n                Join OSMP Volunteer Naturali...
# 9   \n                Come join Jane in an excitin...
# 10  \n                Come join Jane in an excitin...

# %%
eventDetails.replace('\n', '', regex=True, inplace=True)

# %%
eventDetails
# Out:
#                                            Event Name  \
# 0                OSMP and the Arts: Flores de Migajon
# 1   Fun for the Whole Flock: A Playful Birding Pro...
# 2       Recovery and Wellness Series: A Wellness Walk
# 3         Every Day is Earth Day: A Biodiversity Hike
# 4        Adventure with a Ranger: Foundations of OSMP
# 5     Connection in Nature (for Older Adults age 60+)
# 6   Recovery and Wellness Series: Conscious Reconn...
# 7                    Spring Beauty: A Wildflower Hike
# 8                                Connection in Nature
# 9         Older Adults West Boulder Neighborhood Walk
# 10        Older Adults West Boulder Neighborhood Walk
#
#                                         Date and Time  \
# 0     Saturday, 13 April 2024 |   01:00 PM        ...
# 1     Sunday, 14 April 2024 |   12:30 PM          ...
# 2     Saturday, 20 April 2024 |   09:00 AM        ...
# 3     Sunday, 21 April 2024 |   03:00 PM          ...
# 4     Sunday, 21 April 2024 |   10:00 AM          ...
# 5     Wednesday, 24 April 2024 |   10:00 AM       ...
# 6     Saturday, 27 April 2024 |   09:00 AM        ...
# 7     Sunday, 28 April 2024 |   01:00 PM          ...
# 8     Tuesday, 30 April 2024 |   10:00 AM         ...
# 9        Thursday, 25 April 2024 |   09:00 AM
# 10         Thursday, 23 May 2024 |   09:00 AM
#
#                                     Event Description
# 0                   Acompaña a Luna Cultura y Espa...
# 1                   Let your playful self-fly and ...
# 2                   Geared towards those in recove...
# 3                   From vast prairies to rugged p...
# 4                   New to OSMP or looking to beco...
# 5                   Join OSMP Volunteer Naturalist...
# 6                   A program geared towards those...
# 7                   Springtime in Boulder brings s...
# 8                   Join OSMP Volunteer Naturalist...
# 9                   Come join Jane in an exciting,...
# 10                  Come join Jane in an exciting,...
